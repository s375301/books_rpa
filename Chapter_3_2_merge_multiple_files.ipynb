# %%
# full code

#-*-coding:euc-kr

"""
Peter's Code
Clone Code w/ 6개월 치 업무를 하루만에 끝내는 업무 자동화
Last Modification : 2021.11.23
"""

# import
import time
import random
import os
import shutil

#
print("Process Start.")
start_time = time.time()

# iterations
NUM_SAMPLES = 1000

# def
alphabet_samples = "abcdefghizklmnopqrstuvwxyz1234567890"

def random_string(length):
    result = ""
    for i in range(length):
        result += random.choice(alphabet_samples)
    return result

# def
first_name_samples = "김이박최정강조윤장임"
middle_name_samples = "민서예지도하주윤채현지"
last_name_samples = "준윤우원호후서연아은진"

def random_name():
    result = ""
    result += random.choice(first_name_samples)
    result += random.choice(middle_name_samples)
    result += random.choice(last_name_samples)
    return result

# os
if os.path.exists("personal_info"):
    shutil.rmtree("personal_info")
os.mkdir("personal_info")

# creating files
for i in range(NUM_SAMPLES):
    name = random_name()

    filename = "personal_info/" + str(i) + "_" + name + ".txt"
    
    outfile = open(filename, 'w')

    outfile.write("name : " + name + "\n")
    outfile.write("age : " + str(time.time())[-2:] + "\n")
    outfile.write("e-mail : " + random_string(8) + "@bhban.com" + "\n") # outfile = write("e-mail :" + random_string(8) + "@bhban.com\n")
    outfile.write("division :" + random_string(3) + "\n")
    outfile.write("telephone : 010-" + str(time.time())[-4:] + str(time.time())[-6:-2] + "\n")
    outfile.write("sex : " + random.choice(["male", "female"]))

    outfile.close()

#
print("Process Done.")
end_time = time.time()
print("Peter's code: " + str(end_time - start_time) + " seconds.")
# Out:
# Process Start.
# Process Done.
# Peter's code: 0.08986020088195801 seconds.

# %% [markdown]
# # RPA code design
# - 목표 정하기
#   1. 결과물을 저장할 빈 파일을 생성한다.
#   1. personal_info 폴더 내부의 내용물을 하나씩 읽어온다.
#   1. 결과물을 저장할 파일에 내용물을 옮겨 적는다.
#   1. 내용물 작성이 완료되어다면 파일을 종료한다.
# - 목표를 달성하는 데 필요한 작업 쪼개기
#   1. personal_info 폴더 안의 내용물을 목록으로 만들기
#   1. 목록 안의 내용물을 처음부터 끝까지 훑으며, 한 개씩 파일을 읽어오기
#   1. 읽어온 파일에서 내용물을 뽑아내기
#   1. 파일에 내용을 기록하고 저장하기

# %% [markdown]
# #### 1. personal_info 폴더 안의 내용물을 목록으로 만드는 방법
# - ```os.listdir()```: 폴더 내의 내용물을 받아 리스트 형태로 가공해주는 함수

# %%
os.listdir("personal_info")[:5]
# Out:
# ['889_임지후.txt', '945_이주은.txt', '53_김예윤.txt', '447_이윤은.txt', '508_장윤후.txt']

# %% [markdown]
# #### 2. 목록 안의 내용물을 처음부터 끝까지 훑으며, 한 개씩 파일을 읽어오기
# - for loop

# %%
files = os.listdir("personal_info")
for i in range(5): # len(files)
    print(i)
    print(files[i])
# Out:
# 0
# 889_임지후.txt
# 1
# 945_이주은.txt
# 2
# 53_김예윤.txt
# 3
# 447_이윤은.txt
# 4
# 508_장윤후.txt

# %%
for i, filenames in enumerate(files):
    print(filenames)
    if i == 5:
        break
# Out:
# 889_임지후.txt
# 945_이주은.txt
# 53_김예윤.txt
# 447_이윤은.txt
# 508_장윤후.txt
# 908_박민호.txt

# %% [markdown]
# #### 3. 읽어온 파일에서 내용물을 뽑아내기

# %%
files = os.listdir("personal_info")

test_file = open("personal_info/" + files[0])
contents = test_file.read()

print(contents)
test_file.close()
# Out:
# name : 임지후
# age : 62
# e-mail : fhh1vzcm@bhban.com
# division : tsp
# telephone : 010-6174-8861
# sex : female

# %% [markdown]
# # Result

# %%
# full code

import time
import os

#
print("Process Start.")
start_time = time.time()

#
directory = "personal_info"
outfile_name = "merged_ID.txt"

#
out_file = open(outfile_name, 'w')
input_files = os.listdir(directory)

#
for filename in input_files:
    
    # exception
    if '.txt' not in filename:
        continue

    #
    file = open(directory + "/" + filename)

    content = file.read()

    out_file.write(content + "\n\n")

    #
    file.close()

out_file.close()

#
print("Process Done.")
end_time = time.time()
print("Peter's code: " + str(end_time - start_time) + " seconds.")
# Out:
# Process Start.
# Process Done.
# Peter's code: 0.028503894805908203 seconds.
