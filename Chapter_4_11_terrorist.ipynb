# %% [markdown]
# # Prepare

# %%
! pip install pyexcel pyexcel-xlsx
# Out:
# ...
#      |████████████████████████████████| 88 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 44 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 242 kB 33.4 MB/s
# ...
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 2.5.9
#     Uninstalling openpyxl-2.5.9:
#       Successfully uninstalled openpyxl-2.5.9
# ...

# %%
# %%writefile create_victims.py
#!usr/bin/bash python
#-*-coding:utf-8

"""
Peter's Code
Clone Code w/ 6개월 치 업무를 하루만에 끝내는 업무 자동화
Last Modification : 2021.12.12
"""

# import
import time
import random
import os
import pyexcel as px
import shutil

#
print("Process Start.")
start_time = time.time()

#
NUM_SAMPLES = 10

#
alphabet_samples = "abcdefghizklmnopqrstuvwxyz1234567890"

first_name_samples = "김이박최정강조윤장임"
middle_name_samples = "민서예지도하주윤채현지"
last_name_samples = "준윤우원호후서연아은진"

#
def random_string(length):
    result = ""

    for i in range(length):
        result += random.choice(alphabet_samples)

    return result


def random_name():
    result = ""

    result += random.choice(first_name_samples)
    result += random.choice(middle_name_samples)
    result += random.choice(last_name_samples)

    return result

#
if os.path.exists("merged_personal_info"):
    shutil.rmtree("merged_personal_info")
os.mkdir("merged_personal_info")

#
HEADER = ["name", "age", "e-mail", "division", "telephone", "sex"]

#
for i in range(NUM_SAMPLES):

    #
    filename = "merged_personal_info/" + str(i) + "_merged_File.xlsx"

    #
    CONTENT = []

    for j in range(random.randint(10, 20)):
        contents = []
        
        contents.append(random_name())
        contents.append(str(time.time())[-2:])
        contents.append(random_string(8) + "@bhban.com")
        contents.append(random_string(3))
        contents.append("010-" + str(time.time())[-4:] + "-" + str(time.time())[-6:-2])
        contents.append(random.choice(["male", "female"]))

        CONTENT.append(contents)

    #
    RESULT = [HEADER] + CONTENT

    #
    px.save_as(array=RESULT, dest_file_name=filename)

#
print("Process Done.")
end_time = time.time()
print("Peter's code " + str(end_time - start_time) + " seconds.")
# Out:
# Overwriting create_victims.py

# %%
# %run create_victims.py
# Out:
# Process Start.
# Process Done.
# Peter's code 0.08522820472717285 seconds.

# %%
random.randint(10, 20)
# Out:
# 10

# %%
RESULT = [HEADER] + CONTENT
RESULT[:5]
# Out:
# [['name', 'age', 'e-mail', 'division', 'telephone', 'sex'],
#  ['장채원', '61', 'nu3sp8uu@bhban.com', 'ao0', '010-1785-.972', 'male'],
#  ['임지은', '68', 'qvbcsx8c@bhban.com', 'nrp', '010-2199-7220', 'female'],
#  ['강서서', '64', '586e5wix@bhban.com', '83d', '010-2183-7221', 'male'],
#  ['박채원', '52', 'cg367s77@bhban.com', 'ii4', '010-2237-9722', 'female']]

# %% [markdown]
# # RPA design code
# - 목표 정하기
#   1. 폴더 안의 파일을 불러오기
#   1. 데이터를 다양한 형태로 변조하기
#   1. 데이터를 일부만 파괴하기
#
# - 목표를 달성하는 데 필요한 작업 쪼개기
#   1. 데이터를 변조하기 위한 규칙 마련하기
#   1. 변조할 데이터를 선택하는 방법을 마련하기

# %% [markdown]
#  #### 1. 데이터를 변조하기 위한 규칙을 마련하기
#  - 미리 리스트에 가짜 데이터를 모아두고, 진짜 데이터와 바꿔치기하면 좀 더 쉽게 달성할 수 있다.

# %% [markdown]
# #### 2. 변조할 데이터를 선택하는 방법을 마련하기
# - ```random.random()``` 함수를 통해 수학적 확률과 비교하여 데이터를 파괴한다.

# %%
# %%writefile terrorist.py
#!usr/bin/bash python
#-*-encoding:utf-8

"""
Peter's Code
Clone Code w/ 6개월 치 업무를 하루만에 끝내는 업무 자동화
Last Modification : 2021.12.12
"""

import time
import os
import pyexcel as px
import sys
import random

#
print("Process Start.")
start_time = time.time()

#
directory = sys.argv[1]
percent = float(sys.argv[2])/100

#
input_files = os.listdir(directory)

TERROR = ["CAT", "Kitten", "Meow", "miaow", "mewing"]

#
total_cnt, cnt = 0, 0

#
for filename in input_files:
    # exception
    if ".xlsx" not in filename:
        continue
    
    data = px.get_array(file_name=directory + "/" + filename)

    os.remove(directory + "/" + filename)

    for i in range(len(data)):
        for j in range(len(data[i])):
            if random.random() < percent:
                data[i][j] = random.choice(TERROR)

                total_cnt += 1
                cnt += 1
            else:
                total_cnt += 1

    px.save_as(array=data, dest_file_name=directory + "/" + filename)

#
print("Process Done.")
end_time = time.time()
print("Peter's code " + str(end_time - start_time) + " seconds.")
# Out:
# Writing terrorist.py

# %%
# %run terrorist.py merged_personal_info 30
# Out:
# Process Start.
# Process Done.
# Peter's code 0.18482685089111328 seconds.

# %%
print(f"Mathematical Probability: {percent:.2%}")
print(f"Empirical Probability: {cnt/total_cnt:.2%}")
# Out:
# Mathematical Probability: 30.00%
# Empirical Probability: 28.47%
